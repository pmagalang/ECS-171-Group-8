# %%
# Can be ignored, just a testbed for getting the data in

# %%
# read image via skimage
from skimage import io, color
from skimage.transform import resize
img = io.imread("../new-spectrograms/disco/0.png")
img = resize(img, (64,64))
img = color.rgb2gray(color.rgba2rgb(img))
img.shape
# Out:
# (64, 64)

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
io.imshow(img)
